# %% [markdown]
# # Sample action picker

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from rich.jupyter import print as rp

# %%
from laife.entities.action import ActionPicker
from laife.params.laife_params import get_laife_params

# %%
chat_config = get_laife_params().llm_services.chat.openai
ap = ActionPicker(chat_config=chat_config)

# %%
mis = "You need to carve a wooden spoon from a piece of wood. You lack the utensil to do so."

action = ap.invoke(mis)
rp(action)


# ActionCraft(
#     reason='I need a utensil to carve the wooden spoon, and crafting a carving
#     knife will allow me to complete my mission.',
#     utensil_name='carving knife',
#     description='A sharp carving knife made from a sturdy piece of wood,
#     designed to help carve out shapes from other pieces of wood.'
# )
