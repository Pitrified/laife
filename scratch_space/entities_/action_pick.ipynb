# %% [markdown]
# # Sample action picker

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from rich.jupyter import print as rp

# %%
from laife.config.chat_openai import CHAT_OPENAI_CONFIG

from laife.entities.action import ActionPicker

# %%
ap = ActionPicker(chat_openai_config=CHAT_OPENAI_CONFIG)

# %%
mis = "You need to carve a wooden spoon from a piece of wood."
mis += " You lack the utensil to do so."

action = ap.invoke(mis)
rp(action)

# Action(
#     act=ActionCraft(object='carving knife',
# description='A sharp knife designed for carving wood.'),
#     reason='I need a utensil to carve the wooden spoon.'
# )
